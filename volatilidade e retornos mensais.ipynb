# %% [markdown]
# <a href="https://colab.research.google.com/github/solarisjuan/google-colab-projetos-ufrj/blob/main/volatilidade%20e%20retornos%20mensais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import yfinance as y
import matplotlib.pyplot as plt
import seaborn as sns

# %%
vale = yf.download('VALE', start ="2019-01-01", end="2023-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
vale
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2019-01-02  12.940000  13.480000  12.920000  13.470000   9.598698  22120700
# 2019-01-03  13.360000  13.380000  12.820000  12.830000   9.142634  27666700
# 2019-01-04  13.350000  14.090000  13.340000  14.020000   9.990627  42880100
# 2019-01-07  14.230000  14.280000  13.800000  13.830000   9.855233  26186100
# 2019-01-08  13.940000  14.150000  13.850000  14.060000  10.019131  20270400
# ...               ...        ...        ...        ...        ...       ...
# 2022-12-23  16.510000  16.790001  16.500000  16.690001  15.824829  13416000
# 2022-12-27  16.639999  16.950001  16.620001  16.879999  16.004978  19991100
# 2022-12-28  17.080000  17.160000  16.830000  16.920000  16.042906  21807400
# 2022-12-29  17.150000  17.230000  16.850000  16.879999  16.004978  19336000
# 2022-12-30  16.830000  17.100000  16.730000  16.969999  16.090315  16455900
#
# [1008 rows x 6 columns]

# %%
vale.plot(figsize=(10,10))
# Out:
# <Axes: xlabel='Date'>

# %%
df=pd.DataFrame(vale)

# %%
retorno_diario=df.pct_change()
retorno_diario.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2019-01-02       NaN       NaN       NaN       NaN        NaN       NaN
# 2019-01-03  0.032458 -0.007418 -0.007740 -0.047513  -0.047513  0.250715
# 2019-01-04 -0.000748  0.053064  0.040562  0.092751   0.092751  0.549881
# 2019-01-07  0.065918  0.013485  0.034483 -0.013552  -0.013552 -0.389318
# 2019-01-08 -0.020379 -0.009104  0.003623  0.016631   0.016631 -0.225910

# %%
retorno_diario.std()
retorno_diario.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
volatilidade=pd.DataFrame(retorno_diario.std(), columns=['vol 1'])
volatilidade.plot()
# Out:
# <Axes: >
